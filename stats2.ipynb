# %% [markdown]
# Assignment 2

# %% [markdown]
# 1. What is a random variable in probability theory?
#
# A random variable is a numerical outcome of a random phenomenon. It assigns a real number to each outcome in a sample space.

# %% [markdown]
# 2. What are the types of random variables?
# Random variables are of two types:
# * Discrete: Takes countable values (e.g., 0, 1, 2…).
# * Continuous: Takes any value in a continuous range (e.g., any real number between 0 and 1).

# %% [markdown]
# 3.  What is the difference between discrete and continuous distributions?
# * Discrete distribution: Probability is assigned to specific values.
# * Continuous distribution: Probability is spread over an interval, and individual points have zero probability.

# %% [markdown]
# 4. What are probability distribution functions (PDF)?
#
# * For discrete variables, it's called the Probability Mass Function (PMF):
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# P(X=x).
#
# * For continuous variables, it's the Probability Density Function (PDF): a curve where the area under the curve over an interval gives the probability.

# %% [markdown]
# 5. How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
#
# * CDF: Gives the probability that a random variable is less than or equal to a value,
# 𝐹
# (
# 𝑥
# )
# =
# 𝑃
# (
# 𝑋
# ≤
# 𝑥
# )
# F(x)=P(X≤x).
#
# * PDF: Describes the relative likelihood of values (for continuous variables).

# %% [markdown]
# 6. What is a discrete uniform distribution?
#
# A discrete uniform distribution assigns equal probability to each of
# 𝑛
# n outcomes. Example: Rolling a fair die.

# %% [markdown]
# 7. What are the key properties of a Bernoulli distribution?
#
# * Only two outcomes: success (1) or failure (0).
# * Defined by parameter
# 𝑝
# p: the probability of success.
#
# * Mean =
# 𝑝
# p, Variance =
# 𝑝
# (
# 1
# −
# 𝑝
# )
# p(1−p).

# %% [markdown]
# 8. What is the binomial distribution, and how is it used in probability?
# * Describes the number of successes in
# 𝑛
# n independent Bernoulli trials.
# * Used when each trial has the same probability
# 𝑝
# p.
# * PMF:
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# (
# 𝑛
# 𝑘
# )
# 𝑝
# 𝑘
# (
# 1
# −
# 𝑝
# )
# 𝑛
# −
# 𝑘
# P(X=k)=(
# k
# n
# ​
#  )p
# k
#  (1−p)
# n−k

# %% [markdown]
# 9. What is the Poisson distribution and where is it applied?
# * Models the number of events occurring in a fixed interval of time or space.
# * Assumes events occur independently and at a constant rate
# 𝜆
# λ.
# * Common in queueing theory, call centers, etc.

# %% [markdown]
# 10. What is a continuous uniform distribution?
#
# All outcomes in an interval
# [
# 𝑎
# ,
# 𝑏
# ]
# [a,b] are equally likely.
#
# PDF is constant:
# 𝑓
# (
# 𝑥
# )
# =
# 1
# 𝑏
# −
# 𝑎
#  for
# 𝑎
# ≤
# 𝑥
# ≤
# 𝑏
# f(x)=
# b−a
# 1
# ​
#   for a≤x≤b

# %% [markdown]
# 11. What are the characteristics of a normal distribution?
# * Bell-shaped, symmetric about the mean
# 𝜇
# μ.
#
# * Fully described by mean
# 𝜇
# μ and standard deviation
# 𝜎
# σ.
# * Common in natural and social phenomena.

# %% [markdown]
# 12. What is the standard normal distribution, and why is it important?
# * A normal distribution with
# 𝜇
# =
# 0
# μ=0 and
# 𝜎
# =
# 1
# σ=1.
# * Used to standardize other normal variables for comparison and statistical testing.

# %% [markdown]
# 13. What is the Central Limit Theorem (CLT), and why is it critical in statistics?
# * CLT states that the sampling distribution of the sample mean approaches a normal distribution as the sample size increases, regardless of the population's distribution.
# * Important because it justifies using the normal model in hypothesis testing and confidence intervals.

# %% [markdown]
# 14.  How does the Central Limit Theorem relate to the normal distribution?
#
# It explains why the normal distribution appears so often in statistics — many averages or sums of random variables tend to be normally distributed due to the CLT.

# %% [markdown]
# 15. What is the application of Z statistics in hypothesis testing?
# * The Z statistic is used to determine how many standard deviations a sample mean is from the population mean under the null hypothesis.
# * Common in:
#     * Testing proportions and means (when population SD is known)
#     * Constructing confidence intervals.
#     * Calculating p-values.

# %% [markdown]
# 16. How do you calculate a Z-score, and what does it represent?
#
# The Z-score tells you how many standard deviations a data point is from the mean. It’s calculated as:
#
# 𝑍
# =
# 𝑋
# −
# 𝜇/
# 𝜎
#
# 𝑋
# X: the data value
#
# 𝜇
# μ: population mean
#
# 𝜎
# σ: population standard deviation
#
# Interpretation:
#
# * 𝑍
# =
# 0
# : data point is at the mean
#
# * Z>0: above the mean
#
# * Z<0: below the mean

# %% [markdown]
# 17. What are point estimates and interval estimates in statistics?
# * Point estimate: A single value used to estimate a population parameter (e.g., sample mean
# 𝑥
# ˉ
# x
# ˉ
#   as an estimate of population mean
# 𝜇
# μ).
# * Interval estimate: A range of values (e.g., confidence interval) believed to contain the parameter with a certain probability.

# %% [markdown]
# 18. What is the significance of confidence intervals in statistical analysis?
#
# Confidence intervals (CI):
# * Provide a range within which the true population parameter is likely to fall.
# * Come with a confidence level (e.g., 95%), meaning that in repeated samples, the interval would capture the parameter 95% of the time.
# * Express uncertainty about the estimate.

# %% [markdown]
# 19. What is the relationship between a Z-score and a confidence interval?
# * Confidence intervals are often based on Z-scores, especially when population variance is known.
# * Example for 95% CI for population mean (when
# 𝜎
# σ is known):
#
# 𝑥
# ˉ
# ±
# 𝑍
# 𝛼
# /
# 2
# ⋅
# 𝜎
# 𝑛
#
#
# Where
# 𝑍
# 𝛼
# /
# 2
# Z
# α/2
# ​
#   is the Z-score corresponding to the desired confidence level (e.g., 1.96 for 95%).

# %% [markdown]
# 20. How are Z-scores used to compare different distributions?
# * Z-scores standardize data, allowing comparison of values from different distributions:
#
# * A score of
# 𝑍
# =
# 2
# Z=2 in both distributions means the value is 2 SDs above the mean, regardless of the original units or scale.

# %% [markdown]
# 21.  What are the assumptions for applying the Central Limit Theorem?
#
# * Independence: Observations must be independent.
# * Identically distributed: Each observation should come from the same distribution.
# * Sample size: Should be "large enough" (commonly
# 𝑛
# ≥
# 30
# n≥30), unless the population is already normal.
# * Finite variance: Population must have a finite mean and variance.

# %% [markdown]
# 22. What is the concept of expected value in a probability distribution?
# The expected value (or mean) is the long-run average outcome of a random variable:
# * Discrete:
# 𝐸
# [
# 𝑋
# ]
# =
# ∑
# 𝑥
# 𝑖
# 𝑃
# (
# 𝑥
# 𝑖
# )
# * Continuous:
# 𝐸
# [
# 𝑋
# ]
# =
# ∫
# −
# ∞
# ∞
# 𝑥
# ⋅
# 𝑓
# (
# 𝑥
# )
#
# 𝑑
# 𝑥
#
# It represents the center or balance point of the distribution.

# %% [markdown]
# 23. How does a probability distribution relate to the expected outcome of a random variable?
# * The probability distribution gives the likelihood of each outcome.
# * The expected value is the weighted average of all possible outcomes, with weights from the distribution.
# * Thus, the expected outcome is driven directly by the structure of the distribution.

# %% [markdown]
# Practical Questions

# %%
#1.Write a Python program to generate a random variable and display its value.
import numpy as np

x = np.random.rand()
print("Random variable (continuous between 0 and 1):", x)
# Out:
# Random variable (continuous between 0 and 1): 0.22975632659419265

# %%
#2.Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

x = np.arange(1, 7)
pmf = randint.pmf(x, 1, 7)  # Discrete uniform over [1, 6]

plt.stem(x, pmf)
plt.title("PMF of Discrete Uniform Distribution (1–6)")
plt.xlabel("Value")
plt.ylabel("Probability")
plt.grid(True)
plt.show()

# %%
#3.Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.
from scipy.stats import bernoulli

def bernoulli_pdf(p, x):
    return bernoulli.pmf(x, p)

print(bernoulli_pdf(0.6, 1))  # Example: p = 0.6, success (1)
# Out:
# 0.6

# %%
#4.Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.
import numpy as np
import matplotlib.pyplot as plt

n, p = 10, 0.5
data = np.random.binomial(n, p, size=1000)

plt.hist(data, bins=range(n+2), edgecolor='black', align='left')
plt.title("Binomial Distribution (n=10, p=0.5)")
plt.xlabel("Successes")
plt.ylabel("Frequency")
plt.show()

# %%
#5.Create a Poisson distribution and visualize it using Python.
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

x = np.arange(0, 15)
pmf = poisson.pmf(x, mu=5)

plt.stem(x, pmf)
plt.title("Poisson Distribution (λ = 5)")
plt.xlabel("Events")
plt.ylabel("Probability")
plt.grid(True)
plt.show()

# %%
#6.Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution.
from scipy.stats import randint

x = np.arange(1, 7)
cdf = randint.cdf(x, 1, 7)

plt.step(x, cdf, where='post')
plt.title("CDF of Discrete Uniform Distribution (1–6)")
plt.xlabel("Value")
plt.ylabel("Cumulative Probability")
plt.grid(True)
plt.show()

# %%
#7.Generate a continuous uniform distribution using NumPy and visualize it.
from scipy.stats import uniform

x = np.linspace(0, 1, 100)
pdf = uniform.pdf(x, loc=0, scale=1)

plt.plot(x, pdf)
plt.title("PDF of Continuous Uniform Distribution (0–1)")
plt.xlabel("Value")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %%
#8.Simulate data from a normal distribution and plot its histogram.
data = np.random.normal(loc=0, scale=1, size=1000)

plt.hist(data, bins=30, edgecolor='black', density=True)
plt.title("Histogram of Normal Distribution (μ=0, σ=1)")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

# %%
#9.Write a Python function to calculate Z-scores from a dataset and plot them.
import scipy.stats as stats

data = np.random.normal(100, 15, size=100)
z_scores = stats.zscore(data)

plt.hist(z_scores, bins=30, edgecolor='black')
plt.title("Z-scores of Dataset")
plt.xlabel("Z-score")
plt.ylabel("Frequency")
plt.show()

# %%
#10.Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.
sample_means = []
for _ in range(1000):
    sample = np.random.exponential(scale=2.0, size=30)  # Non-normal distribution
    sample_means.append(np.mean(sample))

plt.hist(sample_means, bins=30, density=True)
plt.title("CLT Demonstration (Exponential → Normal via Sample Means)")
plt.xlabel("Sample Mean")
plt.ylabel("Density")
plt.show()

# %%
#11.Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.
import numpy as np
import matplotlib.pyplot as plt

means = []
for _ in range(1000):
    sample = np.random.normal(loc=50, scale=10, size=30)
    means.append(np.mean(sample))

plt.hist(means, bins=30, density=True, edgecolor='black')
plt.title("CLT: Distribution of Sample Means (Normal Population)")
plt.xlabel("Sample Mean")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %%
#12.Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1)
from scipy.stats import norm

x = np.linspace(-4, 4, 200)
pdf = norm.pdf(x, loc=0, scale=1)

plt.plot(x, pdf)
plt.title("Standard Normal Distribution (μ=0, σ=1)")
plt.xlabel("Z")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %%
#13.Generate random variables and calculate their corresponding probabilities using the binomial distribution.
from scipy.stats import binom

n, p = 10, 0.5
x = np.arange(0, n+1)
pmf = binom.pmf(x, n, p)

for xi, prob in zip(x, pmf):
    print(f"P(X={xi}) = {prob:.4f}")
# Out:
# P(X=0) = 0.0010
# P(X=1) = 0.0098
# P(X=2) = 0.0439
# P(X=3) = 0.1172
# P(X=4) = 0.2051
# P(X=5) = 0.2461
# P(X=6) = 0.2051
# P(X=7) = 0.1172
# P(X=8) = 0.0439
# P(X=9) = 0.0098
# P(X=10) = 0.0010

# %%
#14.Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution.
from scipy.stats import norm

def z_score(value, mean, std):
    z = (value - mean) / std
    p = norm.cdf(z)
    print(f"Z-score: {z:.2f}, P(Z <= z): {p:.4f}")
    return z

z_score(110, mean=100, std=15)
# Out:
# Z-score: 0.67, P(Z <= z): 0.7475
# 0.6666666666666666

# %%
#15.Implement hypothesis testing using Z-statistics for a sample dataset.
def z_test(sample_mean, population_mean, std_dev, n, alpha=0.05):
    from scipy.stats import norm
    z = (sample_mean - population_mean) / (std_dev / np.sqrt(n))
    p = 2 * (1 - norm.cdf(abs(z)))
    print(f"Z = {z:.2f}, p-value = {p:.4f}")
    if p < alpha:
        print("Reject null hypothesis.")
    else:
        print("Fail to reject null hypothesis.")

z_test(sample_mean=102, population_mean=100, std_dev=5, n=30)
# Out:
# Z = 2.19, p-value = 0.0285
# Reject null hypothesis.

# %%
#16.Create a confidence interval for a dataset using Python and interpret the result.
import scipy.stats as stats

data = np.random.normal(50, 10, size=100)
mean = np.mean(data)
sem = stats.sem(data)
ci = stats.norm.interval(0.95, loc=mean, scale=sem)

print(f"95% Confidence Interval: {ci}")
# Out:
# 95% Confidence Interval: (np.float64(49.36930315190113), np.float64(53.37284406771311))

# %%
#17.Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.
data = np.random.normal(70, 8, size=60)
mean = np.mean(data)
sem = stats.sem(data)
ci = stats.norm.interval(0.95, loc=mean, scale=sem)

print(f"Sample Mean: {mean:.2f}")
print(f"95% Confidence Interval for Mean: {ci}")
# Out:
# Sample Mean: 69.51
# 95% Confidence Interval for Mean: (np.float64(67.5292329938575), np.float64(71.48498022735828))

# %%
#18.Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.
x = np.linspace(40, 100, 200)
pdf = norm.pdf(x, loc=70, scale=10)

plt.plot(x, pdf)
plt.title("PDF of Normal Distribution (μ=70, σ=10)")
plt.xlabel("Value")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %%
#19.Implement hypothesis testing using Z-statistics for a sample dataset?
def z_test(sample_mean, population_mean, std_dev, n, alpha=0.05):
    from scipy.stats import norm
    z = (sample_mean - population_mean) / (std_dev / np.sqrt(n))
    p = 2 * (1 - norm.cdf(abs(z)))
    print(f"Z = {z:.2f}, p-value = {p:.4f}")
    if p < alpha:
        print("Reject null hypothesis.")
    else:
        print("Fail to reject null hypothesis.")

z_test(sample_mean=102, population_mean=100, std_dev=5, n=30)
# Out:
# Z = 2.19, p-value = 0.0285
# Reject null hypothesis.

# %%
#20.Create a confidence interval for a dataset using Python and interpret the result.
import scipy.stats as stats

data = np.random.normal(50, 10, size=100)
mean = np.mean(data)
sem = stats.sem(data)
ci = stats.norm.interval(0.95, loc=mean, scale=sem)

print(f"95% Confidence Interval: {ci}")
# Out:
# 95% Confidence Interval: (np.float64(48.585844781049055), np.float64(52.52641383625218))

# %%
#21.Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.
data = np.random.normal(70, 8, size=60)
mean = np.mean(data)
sem = stats.sem(data)
ci = stats.norm.interval(0.95, loc=mean, scale=sem)

print(f"Sample Mean: {mean:.2f}")
print(f"95% Confidence Interval for Mean: {ci}")
# Out:
# Sample Mean: 69.94
# 95% Confidence Interval for Mean: (np.float64(68.0169649703675), np.float64(71.86814345296443))

# %%
#22.Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.
x = np.linspace(40, 100, 200)
pdf = norm.pdf(x, loc=70, scale=10)

plt.plot(x, pdf)
plt.title("PDF of Normal Distribution (μ=70, σ=10)")
plt.xlabel("Value")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %%
#23.Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.
from scipy.stats import poisson

x = np.arange(0, 20)
cdf = poisson.cdf(x, mu=5)

plt.step(x, cdf, where='post')
plt.title("CDF of Poisson Distribution (λ = 5)")
plt.xlabel("Number of Events")
plt.ylabel("Cumulative Probability")
plt.grid(True)
plt.show()

# %%
#24.Simulate a random variable using a continuous uniform distribution and calculate its expected value.
from scipy.stats import uniform

a, b = 2, 6
data = uniform.rvs(loc=a, scale=b-a, size=1000)
expected_value = np.mean(data)

print(f"Expected Value (sample estimate): {expected_value:.2f}")
# Out:
# Expected Value (sample estimate): 4.03

# %%
#25.Write a Python program to compare the standard deviations of two datasets and visualize the difference.
data1 = np.random.normal(60, 5, 100)
data2 = np.random.normal(60, 15, 100)

plt.hist(data1, bins=30, alpha=0.6, label='Low SD', edgecolor='black')
plt.hist(data2, bins=30, alpha=0.6, label='High SD', edgecolor='black')
plt.legend()
plt.title("Comparison of Standard Deviations")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
#26.Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.
data = np.random.normal(50, 10, 1000)
data_range = np.max(data) - np.min(data)
iqr = np.percentile(data, 75) - np.percentile(data, 25)

print(f"Range: {data_range:.2f}, IQR: {iqr:.2f}")
# Out:
# Range: 72.08, IQR: 13.32

# %%
#27.Implement Z-score normalization on a dataset and visualize its transformation.
from scipy.stats import zscore

data = np.random.normal(100, 20, 500)
z_data = zscore(data)

plt.hist(z_data, bins=30, edgecolor='black')
plt.title("Z-score Normalized Data")
plt.xlabel("Z-score")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
#28.Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.
from scipy.stats import skew, kurtosis

data = np.random.normal(0, 1, 1000)
print(f"Skewness: {skew(data):.2f}")
print(f"Kurtosis: {kurtosis(data):.2f}")  # Excess kurtosis (0 = normal)
# Out:
# Skewness: 0.13
# Kurtosis: -0.15
